# %%
# One-Max関数
# 与えられたバイナリデータの内、1の数を数える
# 1の数が多いほど高評価
def OneMax (binary_data):
    one_count=0 # 1の数カウンタ
    for o in range(n):#繰り返しの範囲を親、もしくは子供のbinaryデータの桁数に合わせる
        if binary_data[o]==1:
            one_count+=1
    print(one_count)

binary_data=[0,1,1,1,0,0,0,0,1,0,1]
OneMax(binary_data)
